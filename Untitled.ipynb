# %%
# !pip install institMove --upgrade
# Out:
# Collecting institMove
#   Downloading institMove-0.0.1-py3-none-any.whl (8.7 kB)
# Installing collected packages: institMove
# Successfully installed institMove-0.0.1
# WARNING: There was an error checking the latest version of pip.

# %%
### MAIN
import institMove.institMovePgk
mf = institMove.institMovePgk.mf_movement()
mf.output_signal()
df = mf.yahoo_api() 
df = mf.differences(df) 
df = mf.cmf(df) 
df1 = mf.cmf_stats(df)
df2 = mf.sub_grouping(df1)
mf.summary_plot(df2)
mf.smoothing(df2)
mf.pearson_spearman_corr(df2)
# Out:
# WARNING: This is for illustration and entertainment purposes ONLY.
# Do NOT use this information for anything. This includes but is not limited to any financial
# decisions, and/or stock, option and/or bond purchases, real estate transactions or any other decision. If you
# disregard this warning you do so at your sole risk and you assume all responsibility for the consequences.
# In using this applicaiton you also agree that you will indemnify Kokoro Analytics, its officers,
# employees, volunteers, vendors and contractors from any damages incured from disregarding this warning.
#
# Press enter if you have read and will abide by the "Warning" statement above.
#
# We use the Chaikin Money Flow indicator. What is the Chaikin Money Flow? See the link below.
# https://www.fidelity.com/learning-center/trading-investing/technical-analysis/technical-indicator-guide/cmf
#
# What is the stock symbol? dg
# The symbol is:  dg
# What the is the group size to be used for the cmf? 46
# average cmf: 0.022019851657551177
# median cmf: 0.021276832884733768
#
# average pos/neg cmf:                cmf
# Category
# Negative -0.054748
# Positive  0.071216
#
# the number of pos/neg cmf:           cmf
# Category
# Negative   91
# Positive  142
#
# Most recent date:  2022-05-24 00:00:00
# For this date the cmf is:  Positive at 0.052963288994329324
# The number of days that the cmf has been in this category is:  41
# The closing stock price for this period is:  $195.95
# Pearsons correlation: 0.498
# Spearmans correlation: 0.529

# %%
# !pip freeze
# Out:
# absl-py==1.0.0
# aiodns==2.0.0
# aiohttp==3.7.3
# aiohttp-socks==0.5.5
# alabaster==0.7.12
# alembic==1.4.1
# anaconda-client==1.7.2
# anaconda-navigator==1.9.7
# anaconda-project==0.8.3
# appmode==0.8.0
# asn1crypto==1.0.1
# astor==0.8.1
# astroid==2.3.1
# astropy==3.2.1
# astunparse==1.6.3
# async-timeout==3.0.1
# atomicwrites==1.3.0
# attrs==20.3.0
# Babel==2.7.0
# backcall==0.1.0
# backports.functools-lru-cache==1.5
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# beautifulsoup4==4.8.0
# bitarray==1.0.1
# bkcharts==0.2
# bleach==3.1.0
# blis==0.7.5
# bokeh==1.3.4
# boto==2.49.0
# boto3==1.19.8
# botocore==1.22.8
# Bottleneck==1.2.1
# bs4==0.0.1
# cached-property==1.5.2
# cachetools==4.2.4
# catalogue==2.0.6
# cchardet==2.1.7
# certifi==2021.10.8
# cffi==1.12.3
# charade==1.0.3
# chardet==3.0.4
# charset-normalizer==2.0.7
# clang==5.0
# click==8.0.3
# cloudpickle==1.2.2
# clyent==1.2.2
# cmfIndicator-pkg==0.0.1
# colorama==0.4.1
# comtypes==1.1.7
# conda==4.7.12
# conda-build==3.18.9
# conda-package-handling==1.6.0
# conda-verify==3.4.2
# confuse==1.4.0
# contextlib2==0.6.0
# cryptography==2.7
# cycler==0.10.0
# cymem==2.0.6
# Cython==0.29.21
# cytoolz==0.10.0
# dask==2.5.2
# databricks-cli==0.14.3
# dataclasses==0.6
# decorator==4.4.0
# defusedxml==0.6.0
# dill==0.3.4
# distributed==2.5.2
# docker==5.0.0
# docutils==0.15.2
# elasticsearch==7.10.1
# entrypoints==0.3
# et-xmlfile==1.0.1
# fake-useragent==0.1.11
# fastcache==1.1.0
# filelock==3.0.12
# finVizFetchPkg==0.0.2
# Flask==1.1.1
# flatbuffers==1.12
# fsspec==0.5.2
# funcy==1.15
# future==0.17.1
# gast==0.3.3
# gensim==4.0.1
# geographiclib==1.50
# geopy==2.1.0
# gevent==1.4.0
# gitdb==4.0.5
# GitPython==3.1.11
# glob2==0.7
# google-auth==2.3.3
# google-auth-oauthlib==0.4.6
# google-pasta==0.2.0
# googletransx==2.4.2
# greenlet==0.4.15
# grpcio==1.32.0
# h5py==2.10.0
# HeapDict==1.0.1
# html5lib==1.0.1
# htmlmin==0.1.12
# idna==3.3
# ImageHash==4.2.0
# imageio==2.6.0
# imagesize==1.1.0
# importlib-metadata==4.8.2
# institMove==0.0.1
# institutional==0.0.3
# ipykernel==5.1.2
# ipython==7.8.0
# ipython_genutils==0.2.0
# ipywidgets==7.5.1
# isort==4.3.21
# itsdangerous==1.1.0
# jdcal==1.4.1
# jedi==0.15.1
# Jinja2==2.11.3
# jmespath==0.10.0
# joblib==1.0.1
# json5==0.8.5
# jsonschema==3.0.2
# jupyter==1.0.0
# jupyter-client==5.3.3
# jupyter-console==6.0.0
# jupyter-core==4.5.0
# jupyterlab==1.1.4
# jupyterlab-server==1.0.6
# jupyterthemes==0.20.0
# keras==2.9.0
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.2
# keyring==18.0.0
# kiwisolver==1.1.0
# lazy-object-proxy==1.4.2
# lesscpy==0.15.0
# libarchive-c==2.8
# libclang==14.0.1
# llvmlite==0.36.0
# locket==0.2.0
# lxml==4.6.4
# Mako==1.1.4
# Markdown==3.3.6
# MarkupSafe==1.1.1
# matplotlib==3.4.1
# mccabe==0.6.1
# menuinst==1.4.16
# missingno==0.4.2
# mistune==0.8.4
# mkl-fft==1.0.14
# mkl-random==1.1.0
# mkl-service==2.3.0
# mlflow==1.16.0
# mock==3.0.5
# moneyFlowIndicator==0.0.2
# mord==0.6
# more-itertools==7.2.0
# mpmath==1.1.0
# msgpack==0.6.1
# multidict==5.1.0
# multipledispatch==0.6.0
# multiprocess==0.70.12.2
# multitasking==0.0.10
# murmurhash==1.0.6
# navigator-updater==0.2.1
# nbconvert==5.6.0
# nbformat==4.4.0
# nest-asyncio==1.4.3
# networkx==2.5.1
# nltk==3.4.5
# nose==1.3.7
# notebook==6.0.1
# numba==0.53.1
# numexpr==2.7.0
# numpy==1.21.6
# numpydoc==0.9.1
# oauthlib==3.1.1
# olefile==0.46
# opencv-python==4.5.4.60
# openpyxl==3.0.0
# opt-einsum==3.3.0
# packaging==21.2
# pandas==1.2.4
# pandas-profiling==2.11.0
# pandocfilters==1.4.2
# parso==0.5.1
# partd==1.0.0
# path.py==12.0.1
# pathlib2==2.3.5
# pathos==0.2.8
# pathy==0.6.1
# patsy==0.5.1
# pep8==1.7.1
# phik==0.11.2
# pickleshare==0.7.5
# Pillow==6.2.0
# pkginfo==1.5.0.1
# plotly==5.6.0
# pluggy==0.13.0
# ply==3.11
# pox==0.3.0
# ppft==1.6.6.4
# preshed==3.0.6
# prometheus-client==0.7.1
# prometheus-flask-exporter==0.18.2
# prompt-toolkit==2.0.10
# protobuf==3.19.1
# protobuf3-to-dict==0.1.5
# psutil==5.6.3
# py==1.8.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycares==3.1.1
# pycodestyle==2.5.0
# pycosat==0.6.3
# pycparser==2.19
# pycrypto==2.6.1
# pycurl==7.43.0.3
# pydantic==1.8.2
# pyflakes==2.1.1
# Pygments==2.4.2
# pyLDAvis==3.3.1
# pylint==2.4.2
# pyodbc==4.0.27
# pyOpenSSL==19.0.0
# pyparsing==2.4.2
# pyreadline==2.1
# pyrsistent==0.15.4
# PySocks==1.7.1
# pytesseract==0.3.8
# pytest==5.2.1
# pytest-arraydiff==0.3
# pytest-astropy==0.5.0
# pytest-doctestplus==0.4.0
# pytest-openfiles==0.4.0
# pytest-remotedata==0.3.2
# python-dateutil==2.8.0
# python-editor==1.0.4
# python-socks==1.1.2
# pytz==2019.3
# PyWavelets==1.0.3
# pywin32==227
# pywinpty==0.5.5
# PyYAML==5.1.2
# pyzmq==18.1.0
# QtAwesome==0.6.0
# qtconsole==4.5.5
# QtPy==1.9.0
# querystring-parser==1.2.4
# requests==2.26.0
# requests-oauthlib==1.3.0
# retirement==0.1.2
# rope==0.14.0
# rsa==4.7.2
# ruamel_yaml==0.15.46
# s3transfer==0.5.0
# sagemaker==2.67.0
# schedule==0.6.0
# scikeras==0.4.1
# scikit-image==0.15.0
# scikit-learn==0.24.2
# scikit-plot==0.3.7
# scipy==1.5.4
# seaborn==0.11.1
# selenium==3.141.0
# Send2Trash==1.5.0
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.15.0
# sklearn==0.0
# smart-open==5.0.0
# smdebug-rulesconfig==1.0.1
# smmap==3.0.4
# snowballstemmer==2.0.0
# sortedcollections==1.1.2
# sortedcontainers==2.1.0
# soupsieve==1.9.3
# spacy==3.1.4
# spacy-legacy==3.0.8
# Sphinx==2.2.0
# sphinxcontrib-applehelp==1.0.1
# sphinxcontrib-devhelp==1.0.1
# sphinxcontrib-htmlhelp==1.0.2
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.2
# sphinxcontrib-serializinghtml==1.1.3
# sphinxcontrib-websupport==1.1.2
# spyder==3.3.6
# spyder-kernels==0.5.2
# SQLAlchemy==1.3.9
# sqlparse==0.4.1
# srsly==2.4.2
# statsmodels==0.10.1
# sympy==1.4
# tables==3.5.2
# tabulate==0.8.9
# tangled-up-in-unicode==0.0.7
# tblib==1.4.0
# tenacity==8.0.1
# tensorboard==2.9.0
# tensorboard-data-server==0.6.1
# tensorboard-plugin-wit==1.8.0
# tensorflow==2.9.0
# tensorflow-estimator==2.9.0
# tensorflow-gpu==2.7.0
# tensorflow-io-gcs-filesystem==0.25.0
# termcolor==1.1.0
# terminado==0.8.2
# testpath==0.4.2
# textblob==0.15.3
# thinc==8.0.12
# threadpoolctl==2.1.0
# toolz==0.10.0
# tornado==6.0.3
# tqdm==4.60.0
# traitlets==4.3.3
# tweepy==3.10.0
# -e git+https://github.com/twintproject/twint.git@4b30fa33991ccdf89c77471382daad3d3bc8c988#egg=twint
# TwitterAPI==2.6.2.1
# typer==0.4.0
# typing-extensions==3.7.4.3
# unicodecsv==0.14.1
# urllib3==1.26.7
# visions==0.6.0
# waitress==2.0.0
# wasabi==0.8.2
# wcwidth==0.1.7
# webencodings==0.5.1
# websocket-client==0.59.0
# Werkzeug==2.0.2
# widgetsnbextension==3.5.1
# win-inet-pton==1.1.0
# win-unicode-console==0.5
# wincertstore==0.2
# wordcloud==1.8.1
# wrapt==1.12.1
# xlrd==1.2.0
# XlsxWriter==1.2.1
# xlwings==0.15.10
# xlwt==1.3.0
# yarl==1.6.3
# yfinance==0.1.67
# zict==1.0.0
# zipp==3.6.0
